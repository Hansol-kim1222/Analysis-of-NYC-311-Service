# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import os
plt.style.use('ggplot')
import re

pd.set_option('display.max_columns',30)
pd.set_option('display.max_rows',30)

# %%
sr_noise_data = pd.read_csv('311_Service_Requests_from_2019_to_Present.csv')
# Out:
# C:\Users\Hanso\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (8,20,31,32,34,35,36,37) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
sr_noise_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7599250 entries, 0 to 7599249
# Data columns (total 42 columns):
#  #   Column                          Dtype
# ---  ------                          -----
#  0   Unique Key                      int64
#  1   Created Date                    datetime64[ns]
#  2   Closed Date                     datetime64[ns]
#  3   Agency                          object
#  4   Agency Name                     object
#  5   Complaint Type                  object
#  6   Descriptor                      object
#  7   Location Type                   object
#  8   Incident Zip                    object
#  9   Incident Address                object
#  10  Street Name                     object
#  11  Cross Street 1                  object
#  12  Cross Street 2                  object
#  13  Intersection Street 1           object
#  14  Intersection Street 2           object
#  15  Address Type                    object
#  16  City                            object
#  17  Landmark                        object
#  18  Facility Type                   object
#  19  Status                          object
#  20  Due Date                        object
#  21  Resolution Description          object
#  22  Resolution Action Updated Date  object
#  23  Community Board                 object
#  24  BBL                             float64
#  25  Borough                         object
#  26  X Coordinate (State Plane)      float64
#  27  Y Coordinate (State Plane)      float64
#  28  Open Data Channel Type          object
#  29  Park Facility Name              object
#  30  Park Borough                    object
#  31  Vehicle Type                    object
#  32  Taxi Company Borough            object
#  33  Taxi Pick Up Location           object
#  34  Bridge Highway Name             object
#  35  Bridge Highway Direction        object
#  36  Road Ramp                       object
#  37  Bridge Highway Segment          object
#  38  Latitude                        float64
#  39  Longitude                       float64
#  40  Location                        object
#  41  Noise Descriptor                object
# dtypes: datetime64[ns](2), float64(5), int64(1), object(34)
# memory usage: 2.4+ GB

# %%
sr_noise_data['Created Date'] = pd.to_datetime(sr_noise_data['Created Date'], format = "%m/%d/%Y %I:%M:%S %p")
sr_noise_data['Closed Date'] = pd.to_datetime(sr_noise_data['Closed Date'], format = "%m/%d/%Y %I:%M:%S %p")

# %%
def contains_elements_from(string, lst):
    """This function will return True if 
    a given string contains any element from a
    given list. 
    
    Args: 
    string: input string
    lst: a list of strings 
    
    Returns:
    True or False 
    """
    return any(ele in string for ele in lst)

# %%
def get_description(complaint_descriptor):
    """This function takes in the 'Complaint Type' and 'Descriptor' elements 
    and outputs an appropriate relabel for the new feature 'Noise Descriptor.'
    
    Args:
    complaint_descriptor: contains 2 elements, complaint type and descriptor
    
    Returns:
    string label that will be used for new feature, Noise Descriptor. """
    
    complaint = complaint_descriptor[0]
    descriptor = complaint_descriptor[1]  
    #clean up DEP noise descriptor categories 
    if complaint == "Noise": 
        temp = re.search("(^Noise?[:,]*)([\s\w\/]*)", descriptor).group(2).strip(" ").capitalize()
    elif descriptor == descriptor:
        if descriptor == '21 Collection Truck Noise':
            temp = "truck"
        else:
            temp = descriptor.split("/",2)[0]
    else: 
        return "Unspecified"
        
        
    if contains_elements_from(temp,['dog','animals']):
        temp = "Animal"
    elif contains_elements_from(temp,['Car','Engine','truck','carting','Vehicle','Boat']):
        temp ="Vehicle"
    elif contains_elements_from(temp,['NYPD','News','Other']):
        temp ="Helicopter"
    elif contains_elements_from(temp,['Construction','Jack']):
        temp ="Construction"
    elif contains_elements_from(temp,['Music','Loud music']):
        temp ="Loud Music/Party"
    elif contains_elements_from(temp,['Manufacturing']):
        temp = "Manufacturing"
    elif contains_elements_from(temp,['Other noise sources']):
        temp = "Other Sources"
    return temp

# %%
def get_complaint_type(complaint_descriptor_location):
    """This function takes in the Complaint Type, Descriptor, and Location Type 
    elements and outputs an appropriate relabel for the new feature, 'Noise Complaint Type.'
    
    Args:
    complaint_descriptor_location: contains 3 elements, complaint type, descriptor, and location type
    
    Returns:
    string label that will be used for new feature, Noise Complaint Type."""
    
    complaint = complaint_descriptor_location[0]
    descriptor = complaint_descriptor_location[1]
    location = complaint_descriptor_location[2]
    if complaint == "Noise":
        return "Unspecified"
    elif complaint =="Collection Truck Noise":
        return "Vehicle"
    else:
        temp = re.split('Noise -',complaint)[1].strip(" ").capitalize() 
        if ((temp == "Commercial") & (location == location)):
            temp = location
    return temp

# %%
sr_noise_data["Noise Descriptor"] =\
    sr_noise_data[['Complaint Type','Descriptor']].apply(get_description, axis=1)

# %%
list(enumerate(sr_noise_data["Noise Descriptor"].unique()))
# Out:
# [(0, 'APARTMENT ONLY'),
#  (1, 'Pothole'),
#  (2, 'ENTIRE BUILDING'),
#  (3, 'JANITOR'),
#  (4, 'CEILING'),
#  (5, 'WALL'),
#  (6, 'RADIATOR'),
#  (7, 'PESTS'),
#  (8, 'No Access'),
#  (9, 'DAMP SPOT'),
#  (10, 'MOLD'),
#  (11, 'FLOOR'),
#  (12, 'WATER SUPPLY'),
#  (13, 'Alarms'),
#  (14, 'Dirty Water (WE)'),
#  (15, 'Construction'),
#  (16, 'Animal'),
#  (17, 'WINDOW FRAME'),
#  (18, 'BASIN'),
#  (19, 'Blocked Hydrant'),
#  (20, 'HEAVY FLOW'),
#  (21, 'ROOFING'),
#  (22, 'WINDOW'),
#  (23, 'Possible Water Main Break (Use Comments) (WA1)'),
#  (24, 'Leak (Use Comments) (WA2)'),
#  (25, 'Water Meter Broken'),
#  (26, 'Hydrant Running (WC3)'),
#  (27, 'No Water (WNW)'),
#  (28, 'Posted Parking Sign Violation'),
#  (29, 'Loud Music/Party'),
#  (30, '1 or 2'),
#  (31, 'Banging'),
#  (32, 'Manhole Sunken'),
#  (33, 'No Parking, Standing, Stopping'),
#  (34, 'Partial Access'),
#  (35, 'Hydrant Defective (WC2)'),
#  (36, 'Excessive Water In Basement (WEFB)'),
#  (37, 'Unauthorized Bus Layover'),
#  (38, '1R Missed Recycling-All Materials'),
#  (39, 'E3A Dirty Area'),
#  (40, '1RB Missed Recycling - M'),
#  (41, 'Lead Kit Request (Residential) (L10)'),
#  (42, 'Hydrant Running Full (WA4)'),
#  (43, 'SMOKE DETECTOR'),
#  (44, 'Stop'),
#  (45, 'For One Address'),
#  (46, 'Cave-in'),
#  (47, '2R Bulk-Missed Recy Collection'),
#  (48, 'Hydrant Leaking (WC1)'),
#  (49, 'PAVEMENT'),
#  (50, 'Ewaste appointment'),
#  (51, 'Double Parked Blocking Traffic'),
#  (52, 'Rough, Pitted or Cracked Roads'),
#  (53, 'Tortured'),
#  (54, 'DOOR'),
#  (55, '2 Bulk-Missed Collection'),
#  (56, 'Sewer Backup (Use Comments) (SA)'),
#  (57, 'Blocked Sidewalk'),
#  (58, 'Broken Sidewalk'),
#  (59, 'Air: Odor'),
#  (60, 'Air condition/ventilation equipment'),
#  (61, 'Driver Report'),
#  (62, 'BATHTUB'),
#  (63, 'Street Light Out'),
#  (64, 'REFRIGERATOR'),
#  (65, 'E3 Dirty Sidewalk'),
#  (66, 'E8 Canine Violation'),
#  (67, 'Lamppost Leaning'),
#  (68, '1C Uncollected Xmas Trees'),
#  (69, 'With License Plate'),
#  (70, 'Driver Complaint'),
#  (71, 'Blocked Bike Lane'),
#  (72, 'Defective Hardware'),
#  (73, 'Helicopter'),
#  (74, 'Controller'),
#  (75, 'Loud Talking'),
#  (76, 'Dead Branches in Tree'),
#  (77, 'Vehicle'),
#  (78, 'Rat Sighting'),
#  (79, 'Condition Attracting Rodents'),
#  (80, 'Commercial Overnight Parking'),
#  (81, 'Veh Sgnl Mult Lamps'),
#  (82, 'Lamppost Knocked Down'),
#  (83, 'Yield'),
#  (84, 'WINDOW PANE'),
#  (85, '15 Street Cond'),
#  (86, 'Mouse Sighting'),
#  (87, 'Request Large Bulky Item Collection'),
#  (88, 'Use Indoor'),
#  (89, 'Loud Television'),
#  (90, 'Plate Condition - Shifted'),
#  (91, 'Signs of Rodents'),
#  (92, 'Cons - Contrary'),
#  (93, 'Defacement'),
#  (94, 'Working Contrary To Stop Work Order'),
#  (95, 'Obstructing Public Use'),
#  (96, 'Curb Cut'),
#  (97, 'Illegal Hotel Rooms In Residential Building'),
#  (98, 'Illegal Conversion Of Residential Building'),
#  (99, 'No Certificate Of Occupancy'),
#  (100, 'Plumbing Work - Illegal'),
#  (101, 'Building Permit - None'),
#  (102, 'Hitting Building'),
#  (103, 'Boiler - Defective'),
#  (104, 'Site Conditions Endangering Workers'),
#  (105, 'Chemical Vapors'),
#  (106, 'Unlicensed'),
#  (107, 'Vent'),
#  (108, 'In Public'),
#  (109, 'TOILET'),
#  (110, 'SLOW LEAK'),
#  (111, 'Catch Basin Clogged'),
#  (112, 'Chemical Spill'),
#  (113, 'Manhole Cover Missing (Emergency) (SA3)'),
#  (114, 'E12 Illegal Dumping Surveillance'),
#  (115, 'STEAM PIPE'),
#  (116, 'St Name - Attached to Pole'),
#  (117, 'WINDOW GUARD BROKEN'),
#  (118, 'Air: Smoke, Chimney or vent (AS1)'),
#  (119, 'Sidewalk Violation'),
#  (120, 'Overcharge'),
#  (121, 'Non-Delivery Goods'),
#  (122, 'CABINET'),
#  (123, 'Rooftank Leak Or Overflow (CKO)'),
#  (124, 'BELL'),
#  (125, 'Garbage or Litter'),
#  (126, 'E15 Illegal Postering'),
#  (127, 'Hours of Operation'),
#  (128, '12 Dead Animals'),
#  (129, 'Parking Permit Improper Use'),
#  (130, 'Plate Condition - Noisy'),
#  (131, 'SEWAGE'),
#  (132, 'Toilet Facility'),
#  (133, 'Bus Stop'),
#  (134, 'Illegal Tow'),
#  (135, 'Branch Cracked and Will Fall'),
#  (136, 'False Advertising'),
#  (137, 'Structure - Outdoors'),
#  (138, 'ELECTRIC'),
#  (139, 'Graffiti'),
#  (140, 'GARBAGE'),
#  (141, 'Building Shaking'),
#  (142, '15I Street Condition Ice-Non Storm'),
#  (143, 'DOOR FRAME'),
#  (144, '1 Missed Collection'),
#  (145, 'COOKING GAS'),
#  (146, 'NO LIGHTING'),
#  (147, 'Water Meter Stolen'),
#  (148, 'OUTLET'),
#  (149, 'Ventilation'),
#  (150, 'LED Pedestrian Unit'),
#  (151, 'E9 Snow '),
#  (152, 'Branch or Limb Has Fallen Down'),
#  (153, 'Dog Off Leash'),
#  (154, 'ER1 Resident Recyc. (Owner'),
#  (155, 'Assisted Living'),
#  (156, 'Post'),
#  (157, 'Ped Lamp'),
#  (158, 'Broken Glass'),
#  (159, 'Veh Signal Head'),
#  (160, 'Property'),
#  (161, 'Dead Animal'),
#  (162, 'Unspecified'),
#  (163, 'Veh Signal Lamp'),
#  (164, 'Aided'),
#  (165, 'Damaged Telephone'),
#  (166, 'Building - Vacant, Open And Unguarded'),
#  (167, 'Zoning - Non-Conforming'),
#  (168, 'Sprinkler System - Inadequate'),
#  (169, 'Street Flooding (SJ)'),
#  (170, 'Hydrant Knocked Over'),
#  (171, 'Drag Racing'),
#  (172, 'Crash Cushion Defect'),
#  (173, 'Line'),
#  (174, 'LOW WATER PRESSURE - WLWP'),
#  (175, 'Sewage Odor'),
#  (176, 'School Crossing'),
#  (177, 'DOOR TO DUMBWAITER'),
#  (178, 'Pedestrian Signal'),
#  (179, '1RG Missed Recycling Paper'),
#  (180, 'Neglected'),
#  (181, 'Food Worker Hygiene'),
#  (182, 'Veh Signal Visor'),
#  (183, 'Curb Defect-Metal Protruding'),
#  (184, 'Unauthorized Tree Pruning'),
#  (185, 'E5 Loose Rubbish'),
#  (186, 'Detached Trailer'),
#  (187, 'Failure To Maintain'),
#  (188, 'Failed Street Repair'),
#  (189, 'Illegal. Commercial Use In Resident Zone'),
#  (190, 'Exchange'),
#  (191, 'Electrical Wiring Defective'),
#  (192, 'Egress - Doors Locked'),
#  (193, 'Driver Complaint - Non Passenger'),
#  (194, 'WIRING'),
#  (195, '1RO Missed Recycling Organics'),
#  (196, 'Pothole - Highway'),
#  (197, 'Kitchen'),
#  (198, 'Defective'),
#  (199, 'Overnight Commercial Storage'),
#  (200, 'Speed Limit'),
#  (201, 'No Receipt'),
#  (202, 'Fixture'),
#  (203, 'Payment Not Posted'),
#  (204, 'Trespassing'),
#  (205, 'Amount Owed Dispute'),
#  (206, 'Hitting Power'),
#  (207, 'Trees and Sidewalks Program'),
#  (208, 'Refund'),
#  (209, 'Broken Curb'),
#  (210, 'Missing'),
#  (211, 'Out of Order'),
#  (212, 'Street Light Lamp Dim'),
#  (213, 'Lamppost Base Door'),
#  (214, 'Damaged'),
#  (215, 'Ped Multiple Lamps'),
#  (216, 'Planted More Than 2 Years Ago'),
#  (217, 'Odor'),
#  (218, 'ER9 FOAM VIOL. RETAILER'),
#  (219, '10 Litter Basket '),
#  (220, 'Asbestos Complaint (B1)'),
#  (221, 'Oil Spill On Street, Large (HQL)'),
#  (222, 'Unsafe Worksite'),
#  (223, 'Blocked - ATM'),
#  (224, 'Congestion'),
#  (225, 'Playing in Unsuitable Place'),
#  (226, 'E3B Sidewalk Obstruction'),
#  (227, 'STAIRS'),
#  (228, 'LIGHTING'),
#  (229, 'Lamppost Missing'),
#  (230, 'E13 Throw-Out'),
#  (231, 'Debris - Falling Or In Danger Of Falling'),
#  (232, 'E1 Improper Disposal'),
#  (233, 'Rodents'),
#  (234, 'Sign'),
#  (235, 'E6 Commercial Waste Disposal'),
#  (236, 'Foreign Attachment On Lamppost'),
#  (237, 'Multiple Street Lights Out'),
#  (238, 'Facility Maintenance'),
#  (239, 'Street Light Cycling'),
#  (240, 'Street Light Dayburning'),
#  (241, 'Base Door'),
#  (242, 'Catch Basin Sunken'),
#  (243, 'LED Lense'),
#  (244, 'Air: Odor, Nail Salon (AD8)'),
#  (245, 'POWER OUTAGE'),
#  (246, 'Dishwashing'),
#  (247, 'Permit'),
#  (248, 'Relocation of Bus Stop Shelter'),
#  (249, 'In Prohibited Area'),
#  (250, 'Bent'),
#  (251, 'Trunk Damaged'),
#  (252, 'Removing Wildlife'),
#  (253, 'Truck Route Violation'),
#  (254, 'Bill Received in Error'),
#  (255, 'Affecting Sewer or Foundation'),
#  (256, '3 or More'),
#  (257, 'Failure to Comply with Vacate Order'),
#  (258, 'Fence - None'),
#  (259, 'Failure To Retain Water'),
#  (260, 'Gas Hook-Up'),
#  (261, 'E2A Storage Of Receptacles'),
#  (262, 'Boiler - Fumes'),
#  (263, 'Sewage Leak'),
#  (264, 'Flood Light Lamp Dayburning'),
#  (265, 'Lamppost Wire Exposed'),
#  (266, '14B Derelict Bicycle'),
#  (267, 'E4 18" Law'),
#  (268, 'CARBON MONOXIDE DETECTOR'),
#  (269, 'Catch Basin Grating Missing (SA4)'),
#  (270, 'Photocell (PEC) Missing'),
#  (271, 'Chemical Odor (HD1)'),
#  (272, 'Dog'),
#  (273, 'Pet'),
#  (274, 'Property Refunds and Credits'),
#  (275, 'Street Cleaning - ASP'),
#  (276, 'Contract Dispute'),
#  (277, 'Litter'),
#  (278, 'Use Outside'),
#  (279, 'Installation'),
#  (280, 'Tree Leaning'),
#  (281, 'VENTILATION SYSTEM'),
#  (282, 'Plumbing-Defective'),
#  (283, 'Administration'),
#  (284, 'Plate Noisy'),
#  (285, 'Tree Alive - in Poor Condition'),
#  (286, 'E2 Receptacle Violation'),
#  (287, 'Lamppost Damaged'),
#  (288, 'Cloudy Or Milky Water (QB1)'),
#  (289, 'Police Report Requested'),
#  (290, 'Do Not Enter'),
#  (291, 'Insurance Information Requested'),
#  (292, 'Food Contaminated'),
#  (293, 'Dirty'),
#  (294, 'Sign Missing or Defective'),
#  (295, 'Timer Defect - Fast'),
#  (296, 'One Way'),
#  (297, 'E10 Street Obstruction'),
#  (298, 'Cigarette Sale to Minor'),
#  (299, '12P Dead Deer'),
#  (300, 'Landmark Bldg - Illegal Work'),
#  (301, 'Accessibility Accommodations'),
#  (302, 'Placement'),
#  (303, 'Flood Light Lamp Out'),
#  (304, 'Sewer Odor (SA2)'),
#  (305, 'Manhole Overflow (Use Comments) (SA1)'),
#  (306, 'Illegal Use Of A Hydrant (CIN)'),
#  (307, 'Oil Spill On Street, Small (HQS)'),
#  (308, 'Metal Protruding - Sign Stump'),
#  (309, 'Illness Caused by Drinking Water'),
#  (310, 'Mandated Reporters'),
#  (311, 'Equipment Complaint'),
#  (312, 'Personal STAR Exemption'),
#  (313, 'Chained'),
#  (314, 'Excavation Undermining Adjacent Building'),
#  (315, 'E11 Litter Surveillance'),
#  (316, 'Suspended (Hanging) Scaffolds - No Pmt'),
#  (317, 'Public Complaint - Comm Location'),
#  (318, 'Oil Spill Into Basin'),
#  (319, 'Foreign Attachment On Wood Pole'),
#  (320, 'Pedestrian Ramp Defective'),
#  (321, 'Unclean Condition'),
#  (322, 'Demolition - Unsafe'),
#  (323, 'Update Tenant Information'),
#  (324, 'SRO - Illegal Work'),
#  (325, 'Food Spoiled'),
#  (326, 'Unsafe Chemical, Abandoned (HC2)'),
#  (327, 'MAINTENANCE'),
#  (328, 'ER2 Resident Recyc. (Tenant)'),
#  (329, 'Pigeon Waste'),
#  (330, 'After Hours - Licensed Est'),
#  (331, 'Air: Smoke, Vehicular (AA4)'),
#  (332, 'Food Protection'),
#  (333, 'WiFi'),
#  (334, 'Chronic Stoplight Violation'),
#  (335, 'Structure - Indoors'),
#  (336, 'Cellar Door Defective'),
#  (337, 'Sidewalk Shed'),
#  (338, 'Wall'),
#  (339, 'Culvert Blocked'),
#  (340, 'Hydrant Locking Device Request (Use Comments) (WC5)'),
#  (341, 'Application Renewal'),
#  (342, 'Human Capital'),
#  (343, 'Wireless Antenna'),
#  (344, 'ER5 Comm. Recyc. (Bldg Mgmt)'),
#  (345, 'No Sampling Required, Requested Information (QG2)'),
#  (346, 'BOILER'),
#  (347, 'Jewelry'),
#  (348, 'Blocking Street'),
#  (349, 'Elevator - Dangerous Condition'),
#  (350, 'Billing Dispute'),
#  (351, 'E14 ASP'),
#  (352, 'Traffic Sign or Signal Blocked'),
#  (353, '6 Overflowing Litter Baskets'),
#  (354, 'Manufacturing'),
#  (355, 'Entire Tree Has Fallen Down'),
#  (356, 'Guard Rail - Street'),
#  (357, 'Sidewalk Grating - Defective'),
#  (358, 'Nursing Home'),
#  (359, 'Letter Grading'),
#  (360, 'Glassware Broken'),
#  (361, 'Safety Netting'),
#  (362, 'Grass'),
#  (363, 'Sidewalk Blocked'),
#  (364, 'FIRE ESCAPE'),
#  (365, 'Initial Application'),
#  (366, 'TAC Report'),
#  (367, 'Wear & Tear'),
#  (368, 'Branches Damaged'),
#  (369, 'In Conduit'),
#  (370, 'Street Light Feed'),
#  (371, 'Privately Owned Public Space'),
#  (372, 'Manhole Cover Broken'),
#  (373, 'Traffic Signal Light'),
#  (374, 'Bag'),
#  (375, 'Street Light Lamp Missing'),
#  (376, 'Rodent Sighting'),
#  (377, 'Sidewalk Staircase'),
#  (378, 'Cat'),
#  (379, 'Underground'),
#  (380, 'Concrete In Catch Basin (IEA)'),
#  (381,
#   'Wasting Faucets,Sinks,Flushometer,Urinal,Etc. - Private Residence (CWR)'),
#  (382, 'Wastewater Into Catch Basin (IEB)'),
#  (383, 'Hyd Valve Box Cover Missing (WV2)'),
#  (384, 'Gasoline Spill (IAA)'),
#  (385, 'Roots Damaged'),
#  (386, 'Injured Wildlife'),
#  (387, 'Pedestrian Sign'),
#  (388, 'SPRINKLER'),
#  (389, 'Temporary'),
#  (390, 'Natural Gas In Sewer'),
#  (391, 'Illegal Use Of Hose - Private Residence  (CCR)'),
#  (392, 'Taste'),
#  (393, 'Contact Sign Not Posted'),
#  (394, 'Plate Condition - Open'),
#  (395, '8 Request to Clean Vacant Lot'),
#  (396, 'Junction Box'),
#  (397, 'Enclosure Cap'),
#  (398, 'Scale Inaccurate'),
#  (399, 'Graffiti or Vandalism'),
#  (400, 'Application Appeal'),
#  (401, 'Demand for Cash'),
#  (402, 'Copy of Approval Order'),
#  (403, 'Returns Not Filed'),
#  (404, 'Turn Signal'),
#  (405, 'unknown odor'),
#  (406, 'Graffiti - Highway'),
#  (407, 'Damaged Leg or Pole Bent'),
#  (408, 'Dirt, Debris, Litter Complaint'),
#  (409, 'SIGNAGE MISSING'),
#  (410, 'ER6 Comm. Recyc. (Comm. Tenant)'),
#  (411, 'Beekeeping - Honeybees'),
#  (412, 'Miscellaneous'),
#  (413, '3A Sweeping'),
#  (414, 'Illegal Conversion Of Commercial Bldg'),
#  (415, 'Unsafe Chemical, Storage (HC1)'),
#  (416, 'Retail Store'),
#  (417, 'Time Insufficient'),
#  (418, 'Flooded'),
#  (419, 'Clear Street Light'),
#  (420, 'Adult Establishment'),
#  (421, 'Lights From Parking Lot Shining On Building'),
#  (422, 'Business not in compliance'),
#  (423, 'Support Bracket'),
#  (424, 'Warning Signal'),
#  (425, 'Broken Water Fountain'),
#  (426, 'Community Outreach'),
#  (427, 'Multiple St Lts Dayburning'),
#  (428, 'Ped Flasher'),
#  (429, 'Dry Cleaning Vapors (PERC)'),
#  (430, 'Street Zone Blocked'),
#  (431, 'Plumbing Work - Unlicensed'),
#  (432, 'Push Button'),
#  (433, 'Controller Cabinet'),
#  (434, 'SEWER'),
#  (435, 'Lawn care equipment'),
#  (436, 'Sidewalk Zone Blocked'),
#  (437, 'Price Not Posted'),
#  (438, 'Over Capacity'),
#  (439, 'Flashing Hazard'),
#  (440, 'Wood Pole Wires Exposed'),
#  (441, 'Animal Waste'),
#  (442, 'Underage - Licensed Est'),
#  (443, 'High Pressure to Take on Loan'),
#  (444, 'Tree Trunk Split'),
#  (445, '3B Sweeping'),
#  (446, 'MAILBOX'),
#  (447, 'No Shelter'),
#  (448, 'Debt Not Owed'),
#  (449, 'Vendor'),
#  (450, 'Office of Preventive Technical Assistance'),
#  (451, 'Investigative Inspection'),
#  (452, 'E1A Litter Basket '),
#  (453, 'General Counsel'),
#  (454, 'Unauthorized Tree Removal'),
#  (455, 'Chronic Speeding'),
#  (456, 'Door Lock'),
#  (457, 'Pigeon Odor'),
#  (458, 'Sidewalk Collapsed'),
#  (459, 'Building'),
#  (460, 'Sign - In Danger Of Falling'),
#  (461, 'Elevator - Multiple Devices On Property'),
#  (462, 'Hangers'),
#  (463, 'Heating Problem'),
#  (464, 'Plate Condition - Anti-Skid'),
#  (465, 'Grease In Sewer'),
#  (466, 'Cable'),
#  (467, '22 Weeds'),
#  (468, 'Veh Signal Sec Door'),
#  (469, 'Special Events'),
#  (470, 'Food Worker Illness'),
#  (471, 'ROOF DOOR'),
#  (472, 'Blank Out Matrix Sgn'),
#  (473, 'Unsecured Facility'),
#  (474, 'RAIN GARDEN DEBRIS (SRGDBR)'),
#  (475, 'Plumbing'),
#  (476, 'Glassware Missing'),
#  (477, 'PORCH'),
#  (478, 'Flood Light Lamp Cycling'),
#  (479, 'Glassware Hanging'),
#  (480, 'Social Distancing'),
#  (481, 'Wildlife Sighting'),
#  (482, 'Planted Less Than 2 Years Ago'),
#  (483, 'GUTTER'),
#  (484, 'Smoking'),
#  (485, 'Fire Alarm Lamp Out'),
#  (486, 'Food Preparation Location'),
#  (487, 'Sway Bar'),
#  (488, 'Electronics'),
#  (489, 'Defective Street Cut (WZZ1)'),
#  (490, 'Conduit'),
#  (491, 'Real Estate Services'),
#  (492, 'EEO'),
#  (493, 'Labor violation'),
#  (494, 'Lost Coin'),
#  (495, 'Tires'),
#  (496, 'Beach'),
#  (497, 'Smoking Violation'),
#  (498, 'Traffic Camera'),
#  (499, 'Lighting'),
#  (500, 'High Water Pressure (WHP)'),
#  (501, 'Rent Discrepancy'),
#  (502, 'Bicycle Chained to Tree'),
#  (503, 'Executive'),
#  (504, '15R Street Cond'),
#  (505, 'Loose Plate'),
#  (506, 'Chemical Spill (IAC)'),
#  (507, 'Snow or Ice'),
#  (508, 'Clothing Damage'),
#  (509, 'Do Not Block the Box'),
#  (510, 'Painted Line'),
#  (511, 'SKYLIGHT'),
#  (512, 'Crane'),
#  (513, 'St Name - Over Intersection'),
#  (514, 'Safety Equipment'),
#  (515, 'Real Property Tax Assessment'),
#  (516, 'Posted Notice Or Order Removed'),
#  (517, 'Phone Blocking Sidewalk'),
#  (518, 'Unleashed Dog in Public'),
#  (519, 'New Bus Stop Shelter Placement'),
#  (520, 'Receipt Incomplete'),
#  (521, 'APS'),
#  (522, 'Allergy Information'),
#  (523, 'Domestic Strays'),
#  (524, 'Honorary'),
#  (525, 'Driver Complaint - Passenger'),
#  (526, 'Plate Missing'),
#  (527, 'Harassment'),
#  (528, 'Non-Disclosure of Fees'),
#  (529, 'New Con Ed Service Request'),
#  (530, 'Catch Basin Search (SC2)'),
#  (531, 'Handwashing'),
#  (532, 'RPIE - Filing and Technical Issues'),
#  (533, '15S Re-Plow'),
#  (534, 'Bare Hands in Contact w'),
#  (535, 'Lost Property'),
#  (536, 'Hitting Power Lines'),
#  (537, 'Foundation'),
#  (538, 'Mandatory Tip'),
#  (539, 'Clothing'),
#  (540, 'Bracket Arm Missing'),
#  (541, 'Restaurant'),
#  (542, 'Unlicensed Vendors'),
#  (543, 'Snow Removal Requested'),
#  (544, 'ECR Commercial Routing Sticker'),
#  (545, 'Closed without Notice'),
#  (546, 'Food Worker Activity'),
#  (547, 'Mass Gathering'),
#  (548, 'Personal Exemptions'),
#  (549, 'Illegal'),
#  (550, 'Employment Agency'),
#  (551, 'Unsafe Use of Playground'),
#  (552, 'House'),
#  (553, 'Advertising Sign'),
#  (554, 'Tax Commission Rules'),
#  (555, 'Plants- Noise Related Problems (PN1)'),
#  (556, 'Dead End Signal'),
#  (557, 'Prohibited Item Sale to Minor'),
#  (558, 'Personal DHE Exemption'),
#  (559, 'Nuisance'),
#  (560, 'Time Clock Maladjusted'),
#  (561, 'Improper Sale of Items'),
#  (562, 'Information Technology'),
#  (563, 'Air: Odor, Sweet From Unknown Source (AZ1)'),
#  (564, 'In-Line Fuse Missing'),
#  (565, 'Maintenance Cover'),
#  (566, 'On Messenger'),
#  (567, 'Oil, Grease In Water (QD1)'),
#  (568, 'Bike Rack Repair'),
#  (569, 'In Post Base'),
#  (570, 'Facilities Management'),
#  (571, 'Broken Fence'),
#  (572, 'Required Signage Not Posted'),
#  (573, 'No Permit or License'),
#  (574, 'Sodium Warning'),
#  (575, 'Plants- Odor Related Problems (PO1)'),
#  (576, 'Media Inquiries'),
#  (577, 'Energy'),
#  (578, 'Graffiti - Bridge'),
#  (579, 'Elevator - Single Device On Property'),
#  (580, 'Mast Arm'),
#  (581, 'Material Storage - Unsafe'),
#  (582, 'Sewer Break (SBR)'),
#  (583, 'Highway Fence'),
#  (584, 'Paid in Advance'),
#  (585, 'Snow on Overpass'),
#  (586, 'Fallen Debris from Bridge'),
#  (587, 'Farm Animal'),
#  (588, 'Fixture(S)'),
#  (589, 'Electronics Store'),
#  (590, 'Flood Light Lamp Dim'),
#  (591, 'ID Requirement Not Posted'),
#  (592, 'General Bad Condition'),
#  (593, 'Broken'),
#  (594, 'Defective Water Sampling Station (QSS)'),
#  (595, 'Water'),
#  (596, 'Inattentive'),
#  (597, 'Warning Buzzer'),
#  (598, 'Police Report Not Requested'),
#  (599, 'General Maintenance'),
#  (600, 'Guard Rail - Highway'),
#  (601, 'Damaged Toilet'),
#  (602, 'Debris - Excessive'),
#  (603, 'Remove Debris'),
#  (604, 'Non-Delivery of Papers'),
#  (605, 'Rough Pavement'),
#  (606, 'Transducer-Loop'),
#  (607, 'Cellar Door Open'),
#  (608, 'Site Setup Condition'),
#  (609, 'ER4 City Agency (Inst. Recycling)'),
#  (610, 'Unauthorized Film Shoot'),
#  (611, 'Street Fair Vendor'),
#  (612, 'Highway Flooding (SH)'),
#  (613, 'Clear Water With Organisms (Insects, Worms) (QE2)'),
#  (614, 'Misleading Appraisal'),
#  (615, 'Inadequate Support Shoring'),
#  (616, 'Amusement Ride'),
#  (617, 'Street Cave-In'),
#  (618, 'Tow Truck Company'),
#  (619, 'Bracket Arm Broken'),
#  (620, 'Warning Signal Lamp'),
#  (621, 'Speed Board Sign'),
#  (622, 'Bracket Arm Bent'),
#  (623, 'FOIL Request - Request for Records'),
#  (624, 'Door Open with Air Conditioning On'),
#  (625, 'Plumbing Problem'),
#  (626, 'Barrier Condition'),
#  (627, 'Sidewalk Grating - Missing'),
#  (628, 'Unsanitary Condition'),
#  (629, 'Hitting Phone'),
#  (630, 'Secondhand Dealer'),
#  (631, 'Canopy Complaint'),
#  (632, 'American Flag'),
#  (633, 'Garage'),
#  (634, 'Stoop Line'),
#  (635, 'Mobile Food Vendor'),
#  (636, 'Furniture Store'),
#  (637, 'Locker Break-in'),
#  (638, 'Lack of Supplies'),
#  (639, 'Cellar Door New'),
#  (640, 'Contrary To LL 58'),
#  (641, 'Illegal Tree Removal'),
#  (642, 'Storage Warehouse'),
#  (643, 'Enforcement Work Order (DOB)'),
#  (644, 'Snow'),
#  (645, 'Hummock'),
#  (646, 'No or Defective Headphones'),
#  (647, 'Veh Signal Lens'),
#  (648, 'Rental Hall'),
#  (649, 'Property Value'),
#  (650, 'Documents'),
#  (651, 'Driver Report - Passenger'),
#  (652, 'No Idling'),
#  (653, 'Language Access Coordinator'),
#  (654, 'ERV FOAM VIOL. FOOD VENDOR'),
#  (655, 'Coming into Apartment'),
#  (656, 'Tie Rods'),
#  (657, 'OUTLET COVER'),
#  (658, 'Bees'),
#  (659, 'Education Support, Policy, and Practice'),
#  (660, 'Personal SCHE Exemption'),
#  (661, 'Remove Hydrant Locking Device (WC6)'),
#  (662, 'Damaged or Missing Ad Box'),
#  (663, 'Home Improvement Contractor'),
#  (664, 'Business Tax'),
#  (665, 'Citywide Procurement'),
#  (666, 'Air Conditioning Problem'),
#  (667, 'RTMS'),
#  (668, '9 Spill'),
#  (669, 'Inadequate or No Heat'),
#  (670, 'Guard Rail - Bridge'),
#  (671, 'Driver Report - Non Passenger'),
#  (672, 'Tattoo Artist Unlicensed'),
#  (673, 'Wood Pole Missing'),
#  (674, 'Sewage'),
#  (675, 'Depression Maintenance'),
#  (676, 'General Business Tax - Refund'),
#  (677, 'Street Con Game'),
#  (678, 'Fallen Debris from Tunnel'),
#  (679, '15X ICE-SNOW COND.'),
#  (680, 'Bracket Arm Loose'),
#  (681, 'Layaway Terms Not Provided'),
#  (682, 'Trash'),
#  (683, 'MCI Abatement'),
#  (684, 'Gender Pricing'),
#  (685, 'Bodega'),
#  (686, '1RE missed collection for E-waste'),
#  (687, 'Co-op or Condo Abatement'),
#  (688, 'General Business Tax - Return filing'),
#  (689, 'Lane Control Signal'),
#  (690, 'City Planning Commission'),
#  (691, 'New Automatic Public Toilet Request'),
#  (692, 'Rooster'),
#  (693, 'Reflector'),
#  (694, 'No Dial Tone'),
#  (695, 'Labor Violation'),
#  (696, '6R Overflowing Recycling Baskets'),
#  (697, 'Fence'),
#  (698, 'Odor In Sewer'),
#  (699, 'Rates Not Posted'),
#  (700, 'High Grass'),
#  (701, 'E30 Transfer Station'),
#  (702, 'Accident - Elevator'),
#  (703, 'Waterway-Color (IHD)'),
#  (704, 'RAIN GARDEN FLOODING (SRGFLD)'),
#  (705, 'Waterway-Sewage (IHA)'),
#  (706, 'Gas Utility Referral'),
#  (707, 'Large Number of Mosquitoes'),
#  (708, 'Pesticide'),
#  (709, 'Unauthorized Restaurant'),
#  (710, 'Condulet Cover'),
#  (711, 'Unauthorized Posting of Signs'),
#  (712, 'Relocation of Parking Meter'),
#  (713, 'Landlord Inquiries'),
#  (714, 'Request To Open A Hydrant (WC4)'),
#  (715, 'Removing Flowers'),
#  (716, 'Concrete Walls'),
#  (717, 'Peeling Paint Inside Home'),
#  (718, 'FDNY Referral - Pilot'),
#  (719, 'Touchscreen'),
#  (720, 'Waterway-Oil'),
#  (721, 'Biking'),
#  (722, 'Illegal Use Of Hose - Private Residence'),
#  (723, 'Smoke'),
#  (724, 'Elevator In (Fdny) Readiness - None'),
#  (725, 'Food Contains Foreign Object'),
#  (726, '2S Bulk-Storm Related'),
#  (727, 'Damaged Bench'),
#  (728, 'Swimming Pool - Unmaintained'),
#  (729, 'Container - Over 5 Gallons'),
#  (730, 'BBS Failure'),
#  (731, 'Swimming Pool Cover'),
#  (732, 'Roof Gutters'),
#  (733, 'Equipment'),
#  (734, 'Lane Station'),
#  (735, 'Lack of Safety Equipment'),
#  (736, 'Puddle in Ground'),
#  (737, 'Booting Company'),
#  (738, 'Cell Phone Store'),
#  (739, 'Illegal Dumping'),
#  (740, 'Box Cover'),
#  (741, 'Bulky Trash'),
#  (742, 'Driver Compliment'),
#  (743, 'Building Foundation'),
#  (744, 'Remove Stump'),
#  (745, 'Sewer or Drain'),
#  (746, 'Removal Request'),
#  (747, 'Puddle on Roof'),
#  (748, 'Recycling - Paper'),
#  (749, 'General Complaint'),
#  (750, 'Customer Proof of Vaccination Not Checked'),
#  (751, 'DAMAGE STRUCTURE'),
#  (752, 'Accident - Cranes'),
#  (753, 'Inadequate Sweeping'),
#  (754, 'Application Portability'),
#  (755, 'Property Value Dispute'),
#  (756, 'BBQ Outside Authorized Area'),
#  (757, 'Telco Connection Blk'),
#  (758, 'MICROWAVE'),
#  (759, 'Weather Head'),
#  (760, 'Container - Under 5 Gallons'),
#  (761, 'Ped Visor'),
#  (762, 'Toy Gun Sale'),
#  (763, 'Apply Payment or Credit'),
#  (764, 'Payment Misapplied'),
#  (765, 'Equipment Maintenance'),
#  (766, 'Property Misclassification'),
#  (767, 'Door'),
#  (768, 'Lien Sale'),
#  (769, 'Controller Flasher'),
#  (770, 'Puddle on Sidewalk'),
#  (771, 'CSE - Sweep'),
#  (772, 'Illegal Activity'),
#  (773, 'CSC - Monitoring Tracking'),
#  (774, 'Flower Planters'),
#  (775, 'Sustainability Enforcement Work Order'),
#  (776, 'Wrong Amount Paid or Withdrawn'),
#  (777, 'Sidewalk Caf̩'),
#  (778, 'Leaky Roof'),
#  (779,
#   'OTHER INDUSTRIAL WASTE PROBLEM (USE COMMENTS) FOR DEP INTERNAL USE ONLY (IZ)'),
#  (780, 'Dissatisfaction with Provider'),
#  (781, 'Restroom Non-Complaince With Local Law 79'),
#  (782, 'Best - DM Tracking Complaint'),
#  (783, 'Recycling - Metal'),
#  (784, 'After Hours Work - Illegal'),
#  (785, 'Raccoon'),
#  (786, 'Tax Preparer'),
#  (787, 'M.A.R.C.H. Program (Interagency)'),
#  (788, 'Common Areas and Apartment'),
#  (789, 'Electrical Enforcement Work Order (DOB)'),
#  (790, 'Facade (LL11'),
#  (791, 'Plumbing Enforcement Work Order (DOB)'),
#  (792, 'Inspection Work Order (DOB)'),
#  (793, 'Street Not Swept'),
#  (794, 'Bulky Recycling'),
#  (795, 'Best - Low-Rise Tracking Complaint'),
#  (796, 'Delays'),
#  (797, 'Squirrel'),
#  (798, 'Lost and Found'),
#  (799, 'Trash and Bulky Trash'),
#  (800, 'Dirt or Gravel'),
#  (801, 'Merchandise'),
#  (802, 'Dog Waste'),
#  (803, 'Hotel'),
#  (804, 'Bird'),
#  (805, 'Trash or Recycling'),
#  (806, 'Rat or Mouse'),
#  (807, 'Trash or Recycling Not Secure'),
#  (808, 'Inappropriate Behavior'),
#  (809, 'Demolition - No Permit'),
#  (810, 'Overflowing'),
#  (811, 'Roadway'),
#  (812, 'Unsafe Driving'),
#  (813, 'Chronic Dumping'),
#  (814, 'Adjacent Buildings Not Protected'),
#  (815, 'Debt Collection Agency'),
#  (816, 'Weeds or Grass'),
#  (817, '1L Missed Recycling Leaves'),
#  (818, 'Best - High-Rise Tracking Complaint'),
#  (819, 'Poster or Sign'),
#  (820, 'Interior Demo Tracking Complaint'),
#  (821, 'Sidewalk Display'),
#  (822, 'Chained to Public Property'),
#  (823, 'Spilled Garbage'),
#  (824, 'Noise'),
#  (825, 'CSC - Full Demo Tracking'),
#  (826, 'New Basket'),
#  (827, 'Refrigerator or Freezer Door Attached'),
#  (828, 'Announcements'),
#  (829, 'Idling or Blocking Traffic'),
#  (830, 'Blocking Sidewalk or Street'),
#  (831, 'Integrity Complaint Referral'),
#  (832, 'Rodent Bite - PCS Only'),
#  (833, 'Deer'),
#  (834, 'Trash Not Separated from Recycling'),
#  (835, 'Bowstring Truss Tracking Complaint'),
#  (836, 'Syringes'),
#  (837, 'Wireless'),
#  (838, 'Waste Set Out Too Early or Too Late'),
#  (839, 'Laundry'),
#  (840, 'SST Tracking Complaint'),
#  (841, 'Opossum'),
#  (842, 'Gas Station'),
#  (843, 'Blocked Crosswalk'),
#  (844, 'Uncovered'),
#  (845, 'Chronic'),
#  (846, 'Poison Ivy'),
#  (847, 'Semi-Annual Homeless Shelter Inspection: Plumbing'),
#  (848, 'Street Cave-In *Dep Internal Use Only* (SG1)'),
#  (849, 'Mattress or Box Spring Uncovered'),
#  (850, 'Recycling Posters Not Posted'),
#  (851, 'Locksmith'),
#  (852, 'Containers Left Out After Collection'),
#  (853, 'Employee Proof of Vaccination Not Checked'),
#  (854, 'Vaccine Rules Not Posted'),
#  (855, 'Dry Cleaner'),
#  (856, 'Recreation Center'),
#  (857, 'Donation Collection Bin'),
#  (858, 'Dogs or Cats Sold'),
#  (859, 'Collection Days'),
#  (860, 'Semi-Annual Homeless Shelter Inspection: Electrical'),
#  (861, 'Mail Order'),
#  (862, 'Christmas Tree'),
#  (863, 'Illegal Conversion No Access Follow - UP'),
#  (864, 'Restrooms'),
#  (865, 'Garbage'),
#  (866, 'Electronics Repair Store'),
#  (867, 'Food Source'),
#  (868, 'Excise Taxes-Refund'),
#  (869, 'Advice Request'),
#  (870, 'Non-Public Schools'),
#  (871, 'Food Temperature'),
#  (872, 'CSC - Scaffolding'),
#  (873, 'Multi Agency Joint Inspection'),
#  (874, 'Tour Company'),
#  (875, 'Dust Cover'),
#  (876, 'Building Under Structural Monitoring'),
#  (877, 'Workplace - 10 or Less Staff'),
#  (878, 'Deck Inspection'),
#  (879, 'Demolition Notification Received'),
#  (880, 'Safety Inspection-Retaining Walls (May 2005)'),
#  (881, 'Excavation Tracking Complaint'),
#  (882, 'Manhole Cover Missing (Emergency) For Dep Internal Use Only (WF)'),
#  (883, 'Equipment Not Safe'),
#  (884, 'Puddle on Driveway'),
#  (885, 'BUILDING COLLAPSE'),
#  (886, 'Wood Pole Damaged'),
#  (887, 'Stop Temporary'),
#  (888, 'Commercial Not For Profit Exemption'),
#  (889, 'Catch Basin Connection Broken *Dep Internal Use Only* (SC5)'),
#  (890, 'Special Agency Projects'),
#  (891, 'Structurally Compromised Building (LL33'),
#  (892, 'Fountain - Over 5 Gallons'),
#  (893, 'Blocking Sidewalk'),
#  (894, 'In Common Areas'),
#  (895, 'Defective Catch Basin'),
#  (896, 'Wood Pole Leaning'),
#  (897, 'Zoning and Land Use Questions'),
#  (898, 'On Structure'),
#  (899, 'Summer Camp'),
#  (900, 'CMU Communication'),
#  (901, 'Lost'),
#  (902, 'Facility General'),
#  (903, 'Unauthorized Climbing'),
#  (904, 'Fountain - Under 5 Gallons'),
#  (905, 'Trauma Counseling'),
#  (906, 'DCP'),
#  (907, 'Strip Paving'),
#  (908, '10A Adopt-A-Basket'),
#  (909, 'Scrap Metal Processor'),
#  (910, 'Basement'),
#  (911, 'Immigration Services'),
#  (912, 'Book'),
#  (913, 'Home Heating Oil Company'),
#  (914, 'Control Panel Damaged'),
#  (915, 'Wood Pole Knocked Down'),
#  (916, 'Dead End Sign'),
#  (917, 'Crack Sealing'),
#  (918, 'Ped Lens'),
#  (919, 'CP1 Employee Behavior-Bcc'),
#  (920, 'Fire Alarm Lamp Missing'),
#  (921, 'Suspected Street Cut'),
#  (922, '15N Needle'),
#  (923, 'Non-Chronic'),
#  (924, 'Flood Light Lamp Missing'),
#  (925, 'For-profit College'),
#  (926, 'Pawn Broker'),
#  (927, 'Jewelry Appraiser'),
#  (928, 'Exit'),
#  (929, 'Sediment'),
#  (930, 'Fire Globe Missing'),
#  (931, 'Sports Equipment'),
#  (932, 'Indoor Pool Over Capacity'),
#  (933, 'Insects '),
#  (934, 'Scale Dealer'),
#  (935, 'Detour'),
#  (936, 'Gaming Cafe'),
#  (937, 'Curb Violation'),
#  (938, 'Process Server'),
#  (939, 'Fire Hydrant Emergency (FHE)'),
#  (940, 'Travel Agency'),
#  (941, 'Auction House'),
#  (942, 'Pedicab'),
#  (943, 'Funeral Home'),
#  (944, 'Personal Veteran Exemption'),
#  (945, 'Sidewalk Cafe'),
#  (946, 'Animal Odor'),
#  (947, 'Copy of Account Information'),
#  (948, 'Seasonal Mobile Food Vendor License'),
#  (949, 'Medicaid'),
#  (950, 'The ABCs of Housing'),
#  (951, 'Stoop Line Stand License'),
#  (952, 'Copy of Statement'),
#  (953, 'Copy of Notice of Property Value'),
#  (954, 'Condo or Co-op Abatement'),
#  (955, 'Billing Address Incorrect'),
#  (956, 'Status of Appeal'),
#  (957, 'Status of PV Refund'),
#  (958, 'Tax Exemption'),
#  (959, 'Secondhand Dealer Auto License'),
#  (960, 'Housing Information Guide For Tenants and Owners Notice'),
#  (961, 'Condo Billing Issue'),
#  (962, 'Decision and Order'),
#  (963, 'Status of Payment Adjustment'),
#  (964, 'Interest Dispute'),
#  (965, 'Waive Penalty for Late Payment'),
#  (966, 'Food Stamp'),
#  (967, 'Ready NY Guide - Pocket Sized - English'),
#  (968, 'Billing Name Incorrect'),
#  (969, 'Home Ownership Kit'),
#  (970, 'Sample Suspected Gas Leak Notice'),
#  (971, 'Status of Hearing'),
#  (972, 'Filing and Technical Issues'),
#  (973, 'Full Term Mobile Food Vendor License'),
#  (974, 'Commercial Green Roof or Solar Panel Exemption'),
#  (975, 'ACRIS Incorrect'),
#  (976, 'Commercial ICIP or ICAP Exemption'),
#  (977, 'Registration Clearance Request'),
#  (978, 'HomeFirst Down Payment Information'),
#  (979, 'General Vendor Distributor License'),
#  (980, 'Remove Mortgage'),
#  (981, 'Full Term Mobile Food Unit Permit'),
#  (982, 'Commercial 421A Exemption'),
#  (983, 'Applied to Wrong Ticket'),
#  (984, 'Property Address Incorrect'),
#  (985, 'Home Improvement Contractor License'),
#  (986, 'General Street Vendor License'),
#  (987, 'Temporary Food Service Establishment Permit'),
#  (988, 'Mitchell-Lama Housing List'),
#  (989, 'Street Fair Vendor License'),
#  (990, 'Notice of Housing Code Enforcement Issues'),
#  (991, 'Sidewalk Cafe License'),
#  (992, 'Mailed - Not Reflected'),
#  (993, 'Commercial CEP or CRP Exemption'),
#  (994, 'Settlement Reduction Not Shown'),
#  (995, 'New Lead Law Rights and Requirements'),
#  (996, 'Commercial J51 Exemption'),
#  (997, 'Ready NY My Emergency Plan - English'),
#  (998, 'Toxic Chemical'),
#  (999, 'Broken Lock'),
#  ...]

# %%
sr_noise_data["Noise Complaint Type"] =\
    sr_noise_data[['Complaint Type','Descriptor','Location Type']].apply(get_complaint_type, axis=1)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-15-6ce2213b251a> in <module>
#       1 sr_noise_data["Noise Complaint Type"] =\
# ----> 2     sr_noise_data[['Complaint Type','Descriptor','Location Type']].apply(get_complaint_type, axis=1)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in apply(self, func, axis, raw, result_type, args, **kwds)
#    7546             kwds=kwds,
#    7547         )
# -> 7548         return op.get_result()
#    7549
#    7550     def applymap(self, func) -> "DataFrame":
#
# ~\anaconda3\lib\site-packages\pandas\core\apply.py in get_result(self)
#     178             return self.apply_raw()
#     179
# --> 180         return self.apply_standard()
#     181
#     182     def apply_empty_result(self):
#
# ~\anaconda3\lib\site-packages\pandas\core\apply.py in apply_standard(self)
#     269
#     270     def apply_standard(self):
# --> 271         results, res_index = self.apply_series_generator()
#     272
#     273         # wrap results
#
# ~\anaconda3\lib\site-packages\pandas\core\apply.py in apply_series_generator(self)
#     298                 for i, v in enumerate(series_gen):
#     299                     # ignore SettingWithCopy here in case the user mutates
# --> 300                     results[i] = self.f(v)
#     301                     if isinstance(results[i], ABCSeries):
#     302                         # If we have a view on v, we need to make a copy because
#
# <ipython-input-6-a852d80afd5e> in get_complaint_type(complaint_descriptor_location)
#      17         return "Vehicle"
#      18     else:
# ---> 19         temp = re.split('Noise -',complaint)[1].strip(" ").capitalize()
#      20         if ((temp == "Commercial") & (location == location)):
#      21             temp = location
#
# IndexError: list index out of range

# %%
list(enumerate(sr_noise_data["Noise Complaint Type"].unique()))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Noise Complaint Type'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-11-e1d3a525d5d1> in <module>
# ----> 1 list(enumerate(sr_noise_data["Noise Complaint Type"].unique()))
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2900             if self.columns.nlevels > 1:
#    2901                 return self._getitem_multilevel(key)
# -> 2902             indexer = self.columns.get_loc(key)
#    2903             if is_integer(indexer):
#    2904                 indexer = [indexer]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
# -> 2897                 raise KeyError(key) from err
#    2898
#    2899         if tolerance is not None:
#
# KeyError: 'Noise Complaint Type'

# %%
sr_noise_data = sr_noise_data.drop(columns =['Status','Agency Name','Complaint Type',\
                             'Descriptor','Location Type'])

# %%
sr_noise_data['Time Elapsed'] = sr_noise_data['Closed Date']-sr_noise_data['Created Date']

sr_noise_data['Date_created']=pd.DatetimeIndex(sr_noise_data['Created Date']).date
sr_noise_data['Year_month_created']=pd.DatetimeIndex(sr_noise_data['Date_created']).to_period('M').to_timestamp()

sr_noise_data['Year_created'] = pd.DatetimeIndex(sr_noise_data['Created Date']).year
sr_noise_data['Month_created'] = pd.DatetimeIndex(sr_noise_data['Created Date']).month
sr_noise_data['Day_created'] = pd.DatetimeIndex(sr_noise_data['Created Date']).dayofweek
sr_noise_data['Hour_created'] = pd.DatetimeIndex(sr_noise_data['Created Date']).hour

# %%
#1) Calculate Denominator: Total number of complaints created every month
denominator = sr_noise_data.groupby(['Year_month_created'])['Unique Key'].count()

#Add this new feature column to data table via merge 
sr_noise_data = pd.merge(sr_noise_data,denominator, on='Year_month_created')
sr_noise_data.rename(columns={'Unique Key_x': 'Unique Key','Unique Key_y': 'Month_Count_All'},inplace=True)

#2) Calculate Numerator #1: Number of complaints grouped by Noise Descriptor, per month
numerator = sr_noise_data.groupby(['Noise Descriptor',\
                                       'Year_month_created','Month_Count_All'])['Unique Key'].agg('count')
#Add this new feature column to data table via 
sr_noise_data = pd.merge(sr_noise_data,\
                                 numerator,\
                                 how='left',\
                                 on=['Noise Descriptor','Year_month_created','Month_Count_All'])
sr_noise_data.rename(columns={'Unique Key_x': 'Unique Key',\
                                      'Unique Key_y': 'Month_Count_Descriptor'},inplace=True)

#3) Calculate Numerator #2: Number of complaints grouped by Noise Complaint Type, per month
numerator = sr_noise_data.groupby(['Noise Complaint Type',\
                                       'Year_month_created','Month_Count_All'])['Unique Key'].agg('count')
#Add this new feature column to data table via 
sr_noise_data = pd.merge(sr_noise_data,\
                                 numerator,\
                                 how='left',\
                                 on=['Noise Complaint Type','Year_month_created','Month_Count_All'])
sr_noise_data.rename(columns={'Unique Key_x': 'Unique Key',\
                                      'Unique Key_y': 'Month_Count_Complaint_Type'},inplace=True)

# %%
sr_data = sr_noise_data

# %%
sr_data['Complaint Type'].unique().shape
# Out:
# (404,)

# %%
sr_data['Complaint Type'] = sr_data['Complaint Type'].apply(lambda string: string.capitalize())

# %%
pd.set_option('display.max_rows', 200) 

total_complaints = sr_data['Unique Key'].size
number_complaints_by_type = sr_data.groupby('Complaint Type')['Unique Key'].count().sort_values(ascending=False)
percent_complaints_by_type = number_complaints_by_type / total_complaints *100

print(f"Total number of complaints: {sr_data['Unique Key'].size}")

print(f"\nPercent of total complaints logged for each complaint type:")
pd.DataFrame(percent_complaints_by_type).head(10)
# Out:
# Total number of complaints: 7599250
#
# Percent of total complaints logged for each complaint type:
#                          Unique Key
# Complaint Type
# Noise - residential       12.972359
# Illegal parking            9.089779
# Heat/hot water             7.245426
# Noise - street/sidewalk    6.386986
# Blocked driveway           5.230411
# Street condition           2.783893
# Noise - vehicle            2.716281
# Street light condition     2.453979
# Unsanitary condition       2.408277
# Water system               2.018660

# %%
sr_data['Year_created'] = pd.Series(pd.DatetimeIndex(sr_data['Created Date']).year)
sr_data['Month_created'] = pd.Series(pd.DatetimeIndex(sr_data['Created Date']).month)
sr_data['Day_created'] = pd.Series(pd.DatetimeIndex(sr_data['Created Date']).day)
sr_data['Time_created'] = pd.Series(pd.DatetimeIndex(sr_data['Created Date']).time)

sr_data['Year_closed'] = pd.Series(pd.DatetimeIndex(sr_data['Closed Date']).year)
sr_data['Month_closed'] = pd.Series(pd.DatetimeIndex(sr_data['Closed Date']).month)
sr_data['Day_closed'] = pd.Series(pd.DatetimeIndex(sr_data['Closed Date']).day)
sr_data['Time_closed'] = pd.Series(pd.DatetimeIndex(sr_data['Closed Date']).time)

sr_data['Time_elasped'] = sr_data['Closed Date']-sr_data['Created Date']

# %%
complaints_by_type_year = pd.pivot_table(sr_data,\
                                         index=["Complaint Type"],\
                                         columns=["Year_created"], \
                                         values=["Unique Key"],\
                                         aggfunc= lambda values: values.count(),fill_value=0)

sr_data.groupby('Year_created').agg('count')['Unique Key']
# Out:
# Year_created
# 2019    2395124
# 2020    2593407
# 2021    2610719
# Name: Unique Key, dtype: int64

# %%
yearly_percentage = complaints_by_type_year/[971920,2488532,1198776]*100


year_percentage_sorted = yearly_percentage["Unique Key"].sort_values(by=2021, ascending=False)
year_percentage_sorted.head(10)
# Out:
# Year_created                  2019       2020       2021
# Complaint Type
# Noise - residential      23.958042  16.358801  28.850678
# Illegal parking          20.407647   7.807213  24.869033
# Noise - street/sidewalk  10.074389   8.307548  15.074710
# Heat/hot water           21.589534   6.621856  14.679807
# Blocked driveway         14.171537   4.691722  11.927249
# Noise - vehicle           4.432155   3.262687   6.852573
# Street condition          9.101572   2.120447   5.866567
# Unsanitary condition      6.080542   2.495246   5.156760
# Street light condition    7.018170   2.613026   4.441781
# Water system              5.119660   2.031398   4.428851

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns 
#plt.style.use('ggplot')
import plotly.express as px
import plotly.graph_objects as go

# %%
df = sr_noise_data[["Year_month_created","Month_Count_All"]].drop_duplicates()
df["Percent of Total Complaints"] = round((df["Month_Count_All"]/(1664108))*100,2)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-24-cdaf4609981a> in <module>
# ----> 1 df = sr_noise_data[["Year_month_created","Month_Count_All"]].drop_duplicates()
#       2 df["Percent of Total Complaints"] = round((df["Month_Count_All"]/(1664108))*100,2)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2906             if is_iterator(key):
#    2907                 key = list(key)
# -> 2908             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    2909
#    2910         # take() does not accept boolean indexers
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1252             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1253
# -> 1254         self._validate_read_indexer(keyarr, indexer, axis, raise_missing=raise_missing)
#    1255         return keyarr, indexer
#    1256
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1296             if missing == len(indexer):
#    1297                 axis_name = self.obj._get_axis_name(axis)
# -> 1298                 raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    1299
#    1300             # We (temporarily) allow for some missing keys with .loc, except in
#
# KeyError: "None of [Index(['Year_month_created', 'Month_Count_All'], dtype='object')] are in the [columns]"
